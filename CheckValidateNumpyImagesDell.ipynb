# %%
import numpy as np
import os

# %%
dir2check = 'D:/imagedata/Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent_NoNorm64x64x64/'

# %%
imgdatamax = {}
imgdatamin = {}
for i in os.listdir(dir2check):
    img_tmp = np.load(os.path.join(dir2check,i))
    imgdatamax[i] = img_tmp.max()
    imgdatamin[i] = img_tmp.min()

# %%
for key,value in imgdatamax.items():
    if value < 400:
        print(key[:-4], value)
# Out:
# 125005 108.0
# 173972 392.0
# 174978 390.0
# 205047 379.0
# 270102 180.0

# %%
for key,value in imgdatamin.items():
    if value > -1000:
        print(key[:-4], value)
# Out:
# 125005 -949.0
# 127279 -977.0
# 127856 -891.0
# 129143 -985.0
# 132300 -955.0
# 139242 -834.0
# 141368 -901.0
# 152382 -918.0
# 156998 -945.0
# 157355 -809.0
# 158751 -972.0
# 163424 -956.0
# 163587 -900.0
# 165945 -996.0
# 167676 -807.0
# 167678 -900.0
# 169199 -897.0
# 171744 -990.0
# 174978 -846.0
# 175609 -907.0
# 177510 -953.0
# 180385 -972.0
# 183957 -891.0
# 184249 -873.0
# 185521 -849.0
# 187313 -922.0
# 187377 -880.0
# 189117 -913.0
# 194154 -998.0
# 197303 -898.0
# 198750 -997.0
# 203559 -962.0
# 206285 -936.0
# 207311 -797.0
# 209597 -869.0
# 212840 -923.0
# 213813 -921.0
# 216617 -892.0
# 221074 -996.0
# 233445 -867.0
# 240630 -875.0
# 242487 -982.0
# 243795 -927.0
# 247238 -935.0
# 249740 -964.0
# 249849 -935.0
# 250176 -959.0
# 254285 -970.0
# 257947 -896.0
# 260194 -962.0
# 261282 -945.0
# 261388 -939.0
# 264325 -961.0
# 264582 -898.0
# 265174 -892.0
# 265296 -993.0
# 269721 -943.0
# 270102 -555.0
# 273890 -996.0
# 273913 -864.0

# %%
from utilities import utilities

# %%
utilities.check_numpy_images(205047,img_path=dir2check,rotate=False)

# %%
dir2check = 'D:/imagedata/Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent128x128x128_211/'

# %%
imgdatamax = {}
imgdatamin = {}
imgdataavg = {}
for i in os.listdir(dir2check):
    img_tmp = np.load(os.path.join(dir2check,i))
    imgdatamax[i] = img_tmp.max()
    imgdatamin[i] = img_tmp.min()
    imgdataavg[i] = img_tmp.mean()

# %%
np.mean(list(imgdataavg.values()))
# Out:
# 0.5561292074189932

# %% [markdown]
# #### For images in directory Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent32x32x64_211/
#
# - Mean pixel value of all 211 images is 0.71367
#
# #### For images in directory "Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent64x64x64_211/"
#
# - Mean pixel value of all 211 images is 0.6741
#
# #### For images in directory "Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent64x64x96_211/"
#
# - Mean pixel value of all 211 images is 0.6699
#
# #### For images in directory "Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent96x96x96_211/"
#
# - Mean pixel value of all 211 images is 0.6035
#
# #### For images in directory "Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent96x96x128_211/"
#
# - Mean pixel value of all 211 images is 0.6026
#
# #### For images in directory "Eso_NoZeroCentered_DifferentSizes_npyImages/Eso_Numpy_NoZeroCent128x128x128_211/"
#
# - Mean pixel value of all 211 images is 0.5561
#
# # Above values to be used when zero centering the images
#
# ###  image = image - image.mean()
#
# - image.mean is the mean of all the pixel values in all the 211 images
